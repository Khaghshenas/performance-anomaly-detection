# %%
import sys, os
sys.path.append(os.path.abspath(".."))  # add project root
os.chdir("..")

# %%
import numpy as np
import matplotlib.pyplot as plt
from src.environment import ServerAnomalyEnv
from src.agent import DQNAgent
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
pwd
# Out:
# '/home/kawsar-meta/Desktop/performance-anomaly-detection'

# %% [markdown]
# ## Load Server CPU Traces

# %%
from src.train import load_server_data

cpu_datasets = load_server_data()
print(f"{len(cpu_datasets)} servers loaded.")
# Out:
# 1052 servers loaded.

# %% [markdown]
# ## Train and collect training history

# %%
from src.train import train_agent

agent, reward_history = train_agent(cpu_datasets[0], server_id=0)
# Out:
# Server 0 | Episode 1 | Reward: 7.00
# Server 0 | Episode 2 | Reward: 0.00
# Server 0 | Episode 3 | Reward: 28.00
# Server 0 | Episode 4 | Reward: 46.00
# Server 0 | Episode 5 | Reward: 18.00
# Server 0 | Episode 6 | Reward: 27.00
# Server 0 | Episode 7 | Reward: 17.00
# Server 0 | Episode 8 | Reward: 33.00
# Server 0 | Episode 9 | Reward: 37.00
# Server 0 | Episode 10 | Reward: 64.00
# Server 0 | Episode 11 | Reward: 41.00
# Server 0 | Episode 12 | Reward: 69.00
# Server 0 | Episode 13 | Reward: 80.00
# Server 0 | Episode 14 | Reward: 80.00
# Server 0 | Episode 15 | Reward: 37.00
# Server 0 | Episode 16 | Reward: 75.00
# Server 0 | Episode 17 | Reward: 74.00
# Server 0 | Episode 18 | Reward: 84.00
# Server 0 | Episode 19 | Reward: 80.00
# Server 0 | Episode 20 | Reward: 83.00
# Server 0 | Episode 21 | Reward: 87.00
# Server 0 | Episode 22 | Reward: 113.00
# Server 0 | Episode 23 | Reward: 94.00
# Server 0 | Episode 24 | Reward: 95.00
# Server 0 | Episode 25 | Reward: 108.00
# ...

# %%
agent

# %% [markdown]
# ## Training progress

# %% [markdown]
# ### Total Reward per Episode

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot(reward_history)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Agent Learning Curve (Server 0)")
plt.grid(True)
plt.show()
